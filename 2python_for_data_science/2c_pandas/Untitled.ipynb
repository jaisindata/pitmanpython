# %%
import pandas as pd

# %%
myseries = pd.Series(index=[1,2,3],data=[1,2,3])

# %%
type(myseries.values)
# Out:
# numpy.ndarray

# %%
avocados = pd.read_csv('datasets/avocado.csv')

# %%
avocados
# Out:
#        Index        Date  AveragePrice  Total Volume     4046       4225  \
# 0          0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1          1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2          2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3          3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4          4  2015-11-29          1.28      51039.60   941.48   43838.39
# ...      ...         ...           ...           ...      ...        ...
# 18244      7  2018-02-04          1.63      17074.83  2046.96    1529.20
# 18245      8  2018-01-28          1.71      13888.04  1191.70    3431.50
# 18246      9  2018-01-21          1.87      13766.76  1191.92    2452.79
# 18247     10  2018-01-14          1.93      16205.22  1527.63    2981.04
# 18248     11  2018-01-07          1.62      17489.58  2894.77    2356.13
#
#          4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# ...

# %%
avocados['test'] = 123

# %%
avocados
# Out:
#        Index        Date  AveragePrice  Total Volume     4046       4225  \
# 0          0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1          1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2          2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3          3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4          4  2015-11-29          1.28      51039.60   941.48   43838.39
# ...      ...         ...           ...           ...      ...        ...
# 18244      7  2018-02-04          1.63      17074.83  2046.96    1529.20
# 18245      8  2018-01-28          1.71      13888.04  1191.70    3431.50
# 18246      9  2018-01-21          1.87      13766.76  1191.92    2452.79
# 18247     10  2018-01-14          1.93      16205.22  1527.63    2981.04
# 18248     11  2018-01-07          1.62      17489.58  2894.77    2356.13
#
#          4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# ...

# %%
avocados.loc[-1] = ['99999','2018-01-07',1.65,12233.5,123.4,1.2,1.2,1.2,1.2,1.2,0.0,'organic',2018,'xyz',123]

# %%
avocados
# Out:
#         Index        Date  AveragePrice  Total Volume     4046       4225  \
#  0          0  2015-12-27          1.33      64236.62  1036.74   54454.85
#  1          1  2015-12-20          1.35      54876.98   674.28   44638.81
#  2          2  2015-12-13          0.93     118220.22   794.70  109149.67
#  3          3  2015-12-06          1.08      78992.15  1132.00   71976.41
#  4          4  2015-11-29          1.28      51039.60   941.48   43838.39
# ...       ...         ...           ...           ...      ...        ...
#  18245      8  2018-01-28          1.71      13888.04  1191.70    3431.50
#  18246      9  2018-01-21          1.87      13766.76  1191.92    2452.79
#  18247     10  2018-01-14          1.93      16205.22  1527.63    2981.04
#  18248     11  2018-01-07          1.62      17489.58  2894.77    2356.13
# -1      99999  2018-01-07          1.65      12233.50   123.40       1.20
#
#           4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# ...

# %%
avocados.index +=1

# %%
avocados
# Out:
#        Index        Date  AveragePrice  Total Volume     4046       4225  \
# 1          0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 2          1  2015-12-20          1.35      54876.98   674.28   44638.81
# 3          2  2015-12-13          0.93     118220.22   794.70  109149.67
# 4          3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 5          4  2015-11-29          1.28      51039.60   941.48   43838.39
# ...      ...         ...           ...           ...      ...        ...
# 18246      8  2018-01-28          1.71      13888.04  1191.70    3431.50
# 18247      9  2018-01-21          1.87      13766.76  1191.92    2452.79
# 18248     10  2018-01-14          1.93      16205.22  1527.63    2981.04
# 18249     11  2018-01-07          1.62      17489.58  2894.77    2356.13
# 0      99999  2018-01-07          1.65      12233.50   123.40       1.20
#
#          4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# ...

# %%
avocados = avocados.sort_index()

# %%
avocados
# Out:
#        Index        Date  AveragePrice  Total Volume     4046       4225  \
# 0      99999  2018-01-07          1.65      12233.50   123.40       1.20
# 1          0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 2          1  2015-12-20          1.35      54876.98   674.28   44638.81
# 3          2  2015-12-13          0.93     118220.22   794.70  109149.67
# 4          3  2015-12-06          1.08      78992.15  1132.00   71976.41
# ...      ...         ...           ...           ...      ...        ...
# 18245      7  2018-02-04          1.63      17074.83  2046.96    1529.20
# 18246      8  2018-01-28          1.71      13888.04  1191.70    3431.50
# 18247      9  2018-01-21          1.87      13766.76  1191.92    2452.79
# 18248     10  2018-01-14          1.93      16205.22  1527.63    2981.04
# 18249     11  2018-01-07          1.62      17489.58  2894.77    2356.13
#
#          4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# ...

# %%
avocados = avocados.drop(avocados.index[-1])

# %%
avocados
# Out:
#        Index        Date  AveragePrice  Total Volume     4046       4225  \
# 0      99999  2018-01-07          1.65      12233.50   123.40       1.20
# 1          0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 2          1  2015-12-20          1.35      54876.98   674.28   44638.81
# 3          2  2015-12-13          0.93     118220.22   794.70  109149.67
# 4          3  2015-12-06          1.08      78992.15  1132.00   71976.41
# ...      ...         ...           ...           ...      ...        ...
# 18244      6  2018-02-11          1.57      15986.17  1924.28    1368.32
# 18245      7  2018-02-04          1.63      17074.83  2046.96    1529.20
# 18246      8  2018-01-28          1.71      13888.04  1191.70    3431.50
# 18247      9  2018-01-21          1.87      13766.76  1191.92    2452.79
# 18248     10  2018-01-14          1.93      16205.22  1527.63    2981.04
#
#          4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# ...

# %%
import numpy as np
testindex = np.arange(18249)

# %%
avocados.index= list(testindex)

# %%
avocados
# Out:
#        Index        Date  AveragePrice  Total Volume     4046       4225  \
# 0      99999  2018-01-07          1.65      12233.50   123.40       1.20
# 1          0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 2          1  2015-12-20          1.35      54876.98   674.28   44638.81
# 3          2  2015-12-13          0.93     118220.22   794.70  109149.67
# 4          3  2015-12-06          1.08      78992.15  1132.00   71976.41
# ...      ...         ...           ...           ...      ...        ...
# 18244      6  2018-02-11          1.57      15986.17  1924.28    1368.32
# 18245      7  2018-02-04          1.63      17074.83  2046.96    1529.20
# 18246      8  2018-01-28          1.71      13888.04  1191.70    3431.50
# 18247      9  2018-01-21          1.87      13766.76  1191.92    2452.79
# 18248     10  2018-01-14          1.93      16205.22  1527.63    2981.04
#
#          4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# ...

# %%
avocados = avocados.reset_index()

# %%
avocados
# Out:
#        index  Index        Date  AveragePrice  Total Volume     4046  \
# 0          0  99999  2018-01-07          1.65      12233.50   123.40
# 1          1      0  2015-12-27          1.33      64236.62  1036.74
# 2          2      1  2015-12-20          1.35      54876.98   674.28
# 3          3      2  2015-12-13          0.93     118220.22   794.70
# 4          4      3  2015-12-06          1.08      78992.15  1132.00
# ...      ...    ...         ...           ...           ...      ...
# 18244  18244      6  2018-02-11          1.57      15986.17  1924.28
# 18245  18245      7  2018-02-04          1.63      17074.83  2046.96
# 18246  18246      8  2018-01-28          1.71      13888.04  1191.70
# 18247  18247      9  2018-01-21          1.87      13766.76  1191.92
# 18248  18248     10  2018-01-14          1.93      16205.22  1527.63
#
#             4225    4770  Total Bags  Small Bags  Large Bags  XLarge Bags  \
# ...

# %%
avocados.drop(columns=['index'])
# Out:
#        Index        Date  AveragePrice  Total Volume     4046       4225  \
# 0      99999  2018-01-07          1.65      12233.50   123.40       1.20
# 1          0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 2          1  2015-12-20          1.35      54876.98   674.28   44638.81
# 3          2  2015-12-13          0.93     118220.22   794.70  109149.67
# 4          3  2015-12-06          1.08      78992.15  1132.00   71976.41
# ...      ...         ...           ...           ...      ...        ...
# 18244      6  2018-02-11          1.57      15986.17  1924.28    1368.32
# 18245      7  2018-02-04          1.63      17074.83  2046.96    1529.20
# 18246      8  2018-01-28          1.71      13888.04  1191.70    3431.50
# 18247      9  2018-01-21          1.87      13766.76  1191.92    2452.79
# 18248     10  2018-01-14          1.93      16205.22  1527.63    2981.04
#
#          4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# ...

# %%
avocados
# Out:
#        index  Index        Date  AveragePrice  Total Volume     4046  \
# 0          0  99999  2018-01-07          1.65      12233.50   123.40
# 1          1      0  2015-12-27          1.33      64236.62  1036.74
# 2          2      1  2015-12-20          1.35      54876.98   674.28
# 3          3      2  2015-12-13          0.93     118220.22   794.70
# 4          4      3  2015-12-06          1.08      78992.15  1132.00
# ...      ...    ...         ...           ...           ...      ...
# 18244  18244      6  2018-02-11          1.57      15986.17  1924.28
# 18245  18245      7  2018-02-04          1.63      17074.83  2046.96
# 18246  18246      8  2018-01-28          1.71      13888.04  1191.70
# 18247  18247      9  2018-01-21          1.87      13766.76  1191.92
# 18248  18248     10  2018-01-14          1.93      16205.22  1527.63
#
#             4225    4770  Total Bags  Small Bags  Large Bags  XLarge Bags  \
# ...

# %%
avocados[['type','year']].tail(10)
# Out:
#           type  year
# 18239  organic  2018
# 18240  organic  2018
# 18241  organic  2018
# 18242  organic  2018
# 18243  organic  2018
# 18244  organic  2018
# 18245  organic  2018
# 18246  organic  2018
# 18247  organic  2018
# 18248  organic  2018

# %%
type(avocados.loc[:8])
# Out:
# pandas.DataFrame

# %%
avocados_new = avocados[(avocados['region'] == 'TotalUS') \
& (avocados['Date'] > '2018-01-01')]

# %%
avocados_new
# Out:
#        index Index        Date  AveragePrice  Total Volume         4046  \
# 9091    9091     0  2018-03-25          1.03   43409835.75  14130799.10
# 9092    9092     1  2018-03-18          1.05   41386314.12  13707389.51
# 9093    9093     2  2018-03-11          1.09   40449603.12  14089091.05
# 9094    9094     3  2018-03-04          1.07   40741214.05  14439547.46
# 9095    9095     4  2018-02-25          1.06   40021528.76  13829857.87
# 9096    9096     5  2018-02-18          1.08   36709887.49  13262751.42
# 9097    9097     6  2018-02-11          0.97   43167806.09  15870677.70
# 9098    9098     7  2018-02-04          0.87   62505646.52  21620180.90
# 9099    9099     8  2018-01-28          1.09   40171640.84  14551799.50
# 9100    9100     9  2018-01-21          1.08   42939821.55  14218843.83
# 9101    9101    10  2018-01-14          1.20   37299945.22  12600918.24
# 9102    9102    11  2018-01-07          1.13   36703156.72  13730992.75
# ...

# %%
avocados_new = avocados_new.sort_values(['Date'])

# %%
avocados_new
# Out:
#        index Index        Date  AveragePrice  Total Volume         4046  \
# 9102    9102    11  2018-01-07          1.13   36703156.72  13730992.75
# 18225  18225    11  2018-01-07          1.51    1517332.70    129541.43
# 18224  18224    10  2018-01-14          1.59    1476651.08    145680.62
# 9101    9101    10  2018-01-14          1.20   37299945.22  12600918.24
# 9100    9100     9  2018-01-21          1.08   42939821.55  14218843.83
# 18223  18223     9  2018-01-21          1.63    1283987.65    108705.28
# 9099    9099     8  2018-01-28          1.09   40171640.84  14551799.50
# 18222  18222     8  2018-01-28          1.61    1336979.09    118616.17
# 9098    9098     7  2018-02-04          0.87   62505646.52  21620180.90
# 18221  18221     7  2018-02-04          1.53    1384683.41    117922.52
# 9097    9097     6  2018-02-11          0.97   43167806.09  15870677.70
# 18220  18220     6  2018-02-11          1.56    1317000.47     98465.26
# ...

# %%
avocados_new_pivot = avocados_new.pivot(index='Date',columns='type',values='AveragePrice')

# %%
avocados_new_pivot
# Out:
# type        conventional  organic
# Date
# 2018-01-07          1.13     1.51
# 2018-01-14          1.20     1.59
# 2018-01-21          1.08     1.63
# 2018-01-28          1.09     1.61
# 2018-02-04          0.87     1.53
# 2018-02-11          0.97     1.56
# 2018-02-18          1.08     1.52
# 2018-02-25          1.06     1.57
# 2018-03-04          1.07     1.52
# 2018-03-11          1.09     1.52
# 2018-03-18          1.05     1.54
# 2018-03-25          1.03     1.55

# %%
companies = ['Amazon','Apple']
ceos = ['jeffbezos','timcook']
comp_tup = list(zip(companies,ceos))

# %%
comp_df = pd.DataFrame(comp_tup,columns=['comp','ceo'])
comp_df
# Out:
#      comp        ceo
# 0  Amazon  jeffbezos
# 1   Apple    timcook

# %%
tes = avocados.iloc[:]

# %%
tes
# Out:
#    index  Index        Date  AveragePrice  Total Volume     4046       4225  \
# 0      0  99999  2018-01-07          1.65      12233.50   123.40       1.20
# 1      1      0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 2      2      1  2015-12-20          1.35      54876.98   674.28   44638.81
# 3      3      2  2015-12-13          0.93     118220.22   794.70  109149.67
# 4      4      3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 5      5      4  2015-11-29          1.28      51039.60   941.48   43838.39
#
#      4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0    1.20        1.20        1.20        1.20          0.0       organic
# 1   48.16     8696.87     8603.62       93.25          0.0  conventional
# 2   58.33     9505.56     9408.07       97.49          0.0  conventional
# 3  130.50     8145.35     8042.21      103.14          0.0  conventional
# ...

# %%
tes.drop(tes.index[5])
# Out:
#    index  Index        Date  AveragePrice  Total Volume     4046       4225  \
# 0      0  99999  2018-01-07          1.65      12233.50   123.40       1.20
# 1      1      0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 2      2      1  2015-12-20          1.35      54876.98   674.28   44638.81
# 3      3      2  2015-12-13          0.93     118220.22   794.70  109149.67
# 4      4      3  2015-12-06          1.08      78992.15  1132.00   71976.41
#
#      4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0    1.20        1.20        1.20        1.20          0.0       organic
# 1   48.16     8696.87     8603.62       93.25          0.0  conventional
# 2   58.33     9505.56     9408.07       97.49          0.0  conventional
# 3  130.50     8145.35     8042.21      103.14          0.0  conventional
# 4   72.58     5811.16     5677.40      133.76          0.0  conventional
#
#    year  region  test
# 0  2018     xyz   123
# 1  2015  Albany   123
# ...
