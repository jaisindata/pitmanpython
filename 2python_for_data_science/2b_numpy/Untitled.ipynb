# %%
import numpy as np
import imageio

# %%
img_array = imageio.imread('datasets/koala.jpg')
# Out:
# /var/folders/g4/279yvf796w1dxhzl4pryl4sm0000gn/T/ipykernel_31998/806357832.py:1: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   img_array = imageio.imread('datasets/koala.jpg')

# %%
img_array.shape
# Out:
# (720, 902, 3)

# %%
img_array
# Out:
# array([[[ 52,  62,  63],
#         [ 38,  50,  50],
#         [ 20,  31,  35],
#         ...,
#         [ 21,  38,   2],
#         [ 29,  47,   7],
#         [ 41,  60,  15]],
#
#        [[ 60,  70,  71],
#         [ 42,  52,  53],
#         [ 19,  30,  34],
#         ...,
#         [ 19,  37,   0],
#         [ 28,  46,   4],
#         [ 40,  59,  13]],
#
#        [[ 59,  67,  69],
#         [ 40,  50,  51],
#         [ 18,  29,  33],
#         ...,
#         [ 26,  43,   1],
#         [ 33,  50,   5],
#         [ 41,  59,  11]],
#
#        ...,
#
#        [[ 87,  64,  50],
#         [ 83,  59,  47],
#         [ 97,  75,  64],
#         ...,
#         [255, 253, 255],
#         [255, 253, 255],
#         [255, 253, 255]],
#
#        [[ 78,  52,  39],
#         [ 75,  51,  39],
#         [ 84,  62,  51],
#         ...,
#         [255, 253, 255],
#         [255, 253, 255],
#         [255, 253, 255]],
#
#        [[ 71,  45,  32],
#         [ 69,  45,  33],
#         [ 69,  45,  35],
# ...

# %%
import matplotlib.pyplot as plt
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
plt.imshow(img_array)
plt.show()

# %%
plt.show()

# %%
plt.imshow(img_array[300:,200:,:])
plt.show()

# %%
x1,x2 = np.split(img_array,2)

# %%
plt.imshow(x1)
plt.show()

# %%
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[29], line 2
#       1 import pandas as pd
# ----> 2 np.concatenate(x1,x2)
#
# TypeError: only integer scalar arrays can be converted to a scalar index

# %%
countries = pd.read_csv('datasets/countries_of_the_world.csv')
countries.head()
# Out:
#            Country                               Region  Population  \
# 0     Afghanistan         ASIA (EX. NEAR EAST)             31056997
# 1         Albania   EASTERN EUROPE                          3581655
# 2         Algeria   NORTHERN AFRICA                        32930091
# 3  American Samoa   OCEANIA                                   57794
# 4         Andorra   WESTERN EUROPE                            71201
#
#    Area (sq. mi.) Pop. Density (per sq. mi.) Coastline (coast/area ratio)  \
# 0          647500                       48,0                         0,00
# 1           28748                      124,6                         1,26
# 2         2381740                       13,8                         0,04
# 3             199                      290,4                        58,29
# 4             468                      152,1                         0,00
#
#   Net migration Infant mortality (per 1000 births)  GDP ($ per capita)  \
# ...

# %%
birth = countries['Population'].values
plt.plot(birth)
plt.show()

# %%
x=np.array([40,120,34,500,220])
x[x>100]
# Out:
# array([120, 500, 220])

# %%
x = np.arange(
