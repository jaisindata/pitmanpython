# %%
import petl as etl

# %%
fruits_qty = [['apple','orange','mango','grapes'],[25,30,35]]

# %% [raw]
# fruits = etl.facet(fruits_qty,header= ['fruits','quantity'])

# %%
fruits
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 fruits
#
# NameError: name 'fruits' is not defined

# %%
etl
# Out:
# <module 'petl' from '/opt/homebrew/Cellar/jupyterlab/4.5.6/libexec/lib/python3.14/site-packages/petl/__init__.py'>

# %%
help(etl)
# Out:
# Help on package petl:
#
# NAME
#     petl
#
# PACKAGE CONTENTS
#     comparison
#     compat
#     config
#     errors
#     io (package)
#     test (package)
#     transform (package)
#     util (package)
#     version
#
# SUBMODULES
#     avro
#     base
#     basics
#     bcolz
#     conversions
#     counting
#     csv
#     csv_py3
#     db
#     db_create
#     db_utils
#     dedup
#     fills
#     gsheet
#     hashjoins
#     headers
#     html
#     intervals
#     joins
#     json
#     lookups
#     maps
#     materialise
#     misc
#     numpy
#     pandas
#     parsers
#     pickle
#     pytables
#     random
#     reductions
#     regex
#     remotes
#     reshape
#     selects
#     setops
#     sorts
#     sources
#     statistics
#     text
#     timing
#     unpacks
#     validation
#     vis
#     whoosh
#     xls
#     xlsx
#     xml
#
# VERSION
#     1.7.17
#
# FILE
#     /opt/homebrew/Cellar/jupyterlab/4.5.6/libexec/lib/python3.14/site-packages/petl/__init__.py

# %%
etl.
